# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: requests in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yelpapi) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2023.7.22)
# Requirement already satisfied: tqdm in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (4.64.1)

# %% [markdown]
# # Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('/Users/huytran_1/.secret/yelp_api.json', 'r') as f:  
    login = json.load(f)

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s=5.0)

# %% [markdown]
# # Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'Lafayette, LA 70508'
term = 'seafood'

# %%
location.split(',')[0]
# Out:
# 'Lafayette'

# %%
## Specify folder for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Lafayette-seafood.json'

# %% [markdown]
# # Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON folder name is not empty:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Lafayette-seafood.json not found. Saving empty list to file.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %% [markdown]
# # Load JSON FIle and account for previous results

# %% [markdown]
# # Make the first API call to get the first page of data

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 222

# %%
results['region']
# Out:
# {'center': {'longitude': -92.03384399414062, 'latitude': 30.158149285486516}}

# %%
results['businesses']
# Out:
# [{'id': 'l2X390e5Reoxid5v8jOvvQ',
#   'alias': 'the-cajun-table-lafayette',
#   'name': 'The Cajun Table',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DgnTYQ3aADIcqgJ62FNkow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-cajun-table-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 158,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.1542038, 'longitude': -92.0485576},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4510 Ambassador Caffery',
#    'address2': 'Ste D',
#    'address3': None,
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['4510 Ambassador Caffery',
#     'Ste D',
#     'Lafayette, LA 70508']},
#   'phone': '+13378069565',
#   'display_phone': '(337) 806-9565',
#   'distance': 1481.1158373745088},
#  {'id': '_eUkcZsTcwpgQ4g3NtJ8sg',
#   'alias': 'bon-temps-grill-lafayette',
#   'name': 'Bon Temps Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vgoqnsCafAkEBuHn8Ur8wA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bon-temps-grill-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 952,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.2024736, 'longitude': -92.01404300000002},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1211 W Pinhook Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70503',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1211 W Pinhook Rd', 'Lafayette, LA 70503']},
#   'phone': '+13377068850',
#   'display_phone': '(337) 706-8850',
#   'distance': 5283.372658860553},
#  {'id': 'uoE_f470PCOozaATDyRpjA',
#   'alias': 'dons-seafood-lafayette-lafayette',
#   'name': "Don's Seafood - Lafayette",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DfnwRxBw5NE0X5k0ZtcHYg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dons-seafood-lafayette-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 348,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.19525, 'longitude': -92.05694},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4309 Johnston St',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70503',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['4309 Johnston St', 'Lafayette, LA 70503']},
#   'phone': '+13379811141',
#   'display_phone': '(337) 981-1141',
#   'distance': 4684.8587553000725},
#  {'id': '3PZX6hODVlvbaSKAO1j4Ww',
#   'alias': 'the-crawfish-spot-lafayette',
#   'name': 'The Crawfish Spot',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a5KYi8rGGYkdH4qfYZWj3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-crawfish-spot-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 120,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.1899, 'longitude': -92.01352},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1899 W Pinhook Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1899 W Pinhook Rd', 'Lafayette, LA 70508']},
#   'phone': '+13372378533',
#   'display_phone': '(337) 237-8533',
#   'distance': 4034.64516788138},
#  {'id': '79Jr4VhRUe_k687DqEGasA',
#   'alias': 'mandezs-seafood-bar-and-grill-lafayette',
#   'name': "Mandez's Seafood Bar & Grill",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Hu_t6eLYeyGwIregO3MS2Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mandezs-seafood-bar-and-grill-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 79,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.2021924927875,
#    'longitude': -92.0479588471263},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '110 Doucet Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Lafayette',
#    'zip_code': '70503',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['110 Doucet Rd', 'Lafayette, LA 70503']},
#   'phone': '+13377693917',
#   'display_phone': '(337) 769-3917',
#   'distance': 5081.8365288560435},
#  {'id': 'oe356jU3hGaw2caDZcD-aQ',
#   'alias': 'half-shell-oyster-house-lafayette',
#   'name': 'Half Shell Oyster House',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q3wNWJ9m8-s1zJt0po668g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/half-shell-oyster-house-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 135,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.1539250703709,
#    'longitude': -92.0433839410543},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '109 Old Camp Rd',
#    'address2': 'Ste 114',
#    'address3': None,
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['109 Old Camp Rd', 'Ste 114', 'Lafayette, LA 70508']},
#   'phone': '+13374841120',
#   'display_phone': '(337) 484-1120',
#   'distance': 1030.5001933450715},
#  {'id': 'n0RkGJQTMCcdIy-AKk03VQ',
#   'alias': 'uncle-ts-oyster-bar-scott',
#   'name': "Uncle T's Oyster Bar",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gA0o_2pJv4lkFpU-uD-9bg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/uncle-ts-oyster-bar-scott?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 221,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.235258, 'longitude': -92.09492},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1001 St Mary St',
#    'address2': '',
#    'address3': None,
#    'city': 'Scott',
#    'zip_code': '70583',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1001 St Mary St', 'Scott, LA 70583']},
#   'phone': '+13375042285',
#   'display_phone': '(337) 504-2285',
#   'distance': 10390.825149229158},
#  {'id': 'eRdYDjaZcOjpPVF1sAR1cQ',
#   'alias': 'louisiana-crawfish-time-lafayette',
#   'name': 'Louisiana Crawfish Time',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/11SSJLXTA4k3qZmsyLAxSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/louisiana-crawfish-time-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 75,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.156499764300143,
#    'longitude': -92.0238001253646},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2019 Verot School Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['2019 Verot School Rd', 'Lafayette, LA 70508']},
#   'phone': '+13379882645',
#   'display_phone': '(337) 988-2645',
#   'distance': 982.9276526976306},
#  {'id': 'xUmy6KQQluX7enVlSgEEow',
#   'alias': 'prejeans-lafayette-3',
#   'name': "Prejean's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GMMw6XZiLCcLApBKjdf6QA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prejeans-lafayette-3?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 723,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.306143044990996,
#    'longitude': -92.02793106667586},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3480 NE Evangeline Trwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70507',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['3480 NE Evangeline Trwy', 'Lafayette, LA 70507']},
#   'phone': '+13378963247',
#   'display_phone': '(337) 896-3247',
#   'distance': 16465.938790323744},
#  {'id': 'yjbNUqfgeJbkVZzk43frtA',
#   'alias': 'fiery-crab-lafayette',
#   'name': 'Fiery Crab',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_KjOLPGJ9RZOdpLzjC2rJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fiery-crab-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 88,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 30.160371120892343,
#    'longitude': -92.04509659230584},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2330 Kaliste Saloom Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['2330 Kaliste Saloom Rd', 'Lafayette, LA 70508']},
#   'phone': '+13375348118',
#   'display_phone': '(337) 534-8118',
#   'distance': 1109.7051114554888},
#  {'id': 'BRH4kLbKrPJHcxLKYA3q8A',
#   'alias': 'lts-seafood-and-steakhouse-broussard',
#   'name': "LT's Seafood & Steakhouse",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I4GJm5LJHl4_DnnK63w_ng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lts-seafood-and-steakhouse-broussard?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 114,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.137911, 'longitude': -91.970862},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '636 Albertson Pkwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Broussard',
#    'zip_code': '70518',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['636 Albertson Pkwy', 'Broussard, LA 70518']},
#   'phone': '+13378373268',
#   'display_phone': '(337) 837-3268',
#   'distance': 6460.5502132381625},
#  {'id': 'tDGBP8mc2hKLqRFhO_K2Ng',
#   'alias': 'bonefish-grill-lafayette',
#   'name': 'Bonefish Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/o8HDbl4Ma_1aP5oxTxQxnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bonefish-grill-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 133,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.1690661, 'longitude': -92.0356844},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1912 Kaliste Saloom Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1912 Kaliste Saloom Rd', 'Lafayette, LA 70508']},
#   'phone': '+13379810714',
#   'display_phone': '(337) 981-0714',
#   'distance': 1226.7199465421306},
#  {'id': 'mkwRJQWB1Ca_j9aBRXuQPw',
#   'alias': 'dwights-lafayette',
#   'name': "Dwight's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IEBxpTTXc1OKzSAiQJ4ojQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dwights-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 107,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.18548, 'longitude': -92.06778},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4800 Johnston St',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70503',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['4800 Johnston St', 'Lafayette, LA 70503']},
#   'phone': '+13379811241',
#   'display_phone': '(337) 981-1241',
#   'distance': 4465.9283057370185},
#  {'id': 'UiFYIjY5sttbvI0J_zVHOg',
#   'alias': 'acadiana-poboys-and-cajun-cuisine-lafayette',
#   'name': 'Acadiana PoBoys & Cajun Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jt3xkA_Zv-BOQwsL3yEZeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/acadiana-poboys-and-cajun-cuisine-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 39,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.141331, 'longitude': -92.033106},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '2848 Verot School Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['2848 Verot School Rd', 'Lafayette, LA 70508']},
#   'phone': '+13378562511',
#   'display_phone': '(337) 856-2511',
#   'distance': 1871.4517113226073},
#  {'id': 'lYwCOpqW4QB2nRkjb4lmqQ',
#   'alias': 'spoonbill-watering-hole-and-restaurant-lafayette',
#   'name': 'Spoonbill Watering Hole & Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lv24Z6sz6yKuYmqWBrie6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spoonbill-watering-hole-and-restaurant-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 106,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.22094, 'longitude': -92.01872},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '900 Jefferson St',
#    'address2': '',
#    'address3': None,
#    'city': 'Lafayette',
#    'zip_code': '70501',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['900 Jefferson St', 'Lafayette, LA 70501']},
#   'phone': '+13375340585',
#   'display_phone': '(337) 534-0585',
#   'distance': 7130.701048932035},
#  {'id': 'jp6m9Ssgb2sj-Cm9b8gQ6A',
#   'alias': 'dragos-lafayette-lafayette',
#   'name': "Drago's - Lafayette",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6F3_BRhM4rH8GoIsyfRtrg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dragos-lafayette-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 104,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 30.20355, 'longitude': -92.04773},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '3151 Johnston St',
#    'address2': '',
#    'address3': None,
#    'city': 'Lafayette',
#    'zip_code': '70503',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['3151 Johnston St', 'Lafayette, LA 70503']},
#   'phone': '+13377067077',
#   'display_phone': '(337) 706-7077',
#   'distance': 5194.8825057928825},
#  {'id': 'aOIfe9a9WLsp4_azu_S3bA',
#   'alias': 'ruffinos-on-the-river-lafayette',
#   'name': "Ruffino's On The River",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-adHtW796aR1QGn6HZFXBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ruffinos-on-the-river-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 210,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.1787834, 'longitude': -92.0462335},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '921 Camellia Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70508',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['921 Camellia Blvd', 'Lafayette, LA 70508']},
#   'phone': '+13377067333',
#   'display_phone': '(337) 706-7333',
#   'distance': 2722.812534952994},
#  {'id': 'Q4OPHhni8IqZzJmNLIGNOg',
#   'alias': 'blu-basil-wine-and-grill-lafayette-2',
#   'name': 'Blu Basil Wine & Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a13ZFAaa62Jv7E2slCY2JQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blu-basil-wine-and-grill-lafayette-2?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 165,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.1801069418035,
#    'longitude': -92.0716247031156},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5451 Johnston St',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70503',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['5451 Johnston St', 'Lafayette, LA 70503']},
#   'phone': '+13374561120',
#   'display_phone': '(337) 456-1120',
#   'distance': 4376.359631119932},
#  {'id': '1wqSPVCN6zsTl62CHNJW_A',
#   'alias': 'lagneauxs-lafayette',
#   'name': "Lagneaux's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qAV7ThMs7exkK0QLJKpcXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lagneauxs-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 65,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 30.18052, 'longitude': -92.08781},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '445 Ridge Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70506',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['445 Ridge Rd', 'Lafayette, LA 70506']},
#   'phone': '+13379841415',
#   'display_phone': '(337) 984-1415',
#   'distance': 5771.263521558532},
#  {'id': 'XIwKVwG3e8ezLNkd3ZvZ_A',
#   'alias': 'olde-tyme-grocery-lafayette',
#   'name': 'Olde Tyme Grocery',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eE4XmItjHpMFB7nwyLOapQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olde-tyme-grocery-lafayette?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 624,
#   'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.21569, 'longitude': -92.02312},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '218 W St Mary Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Lafayette',
#    'zip_code': '70506',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['218 W St Mary Blvd', 'Lafayette, LA 70506']},
#   'phone': '+13372358165',
#   'display_phone': '(337) 235-8165',
#   'distance': 6481.371950925343}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                             alias  \
# 0   l2X390e5Reoxid5v8jOvvQ                         the-cajun-table-lafayette
# 1   _eUkcZsTcwpgQ4g3NtJ8sg                         bon-temps-grill-lafayette
# 2   uoE_f470PCOozaATDyRpjA                  dons-seafood-lafayette-lafayette
# 3   3PZX6hODVlvbaSKAO1j4Ww                       the-crawfish-spot-lafayette
# 4   79Jr4VhRUe_k687DqEGasA           mandezs-seafood-bar-and-grill-lafayette
# 5   oe356jU3hGaw2caDZcD-aQ                 half-shell-oyster-house-lafayette
# 6   n0RkGJQTMCcdIy-AKk03VQ                         uncle-ts-oyster-bar-scott
# 7   eRdYDjaZcOjpPVF1sAR1cQ                 louisiana-crawfish-time-lafayette
# 8   xUmy6KQQluX7enVlSgEEow                              prejeans-lafayette-3
# 9   yjbNUqfgeJbkVZzk43frtA                              fiery-crab-lafayette
# 10  BRH4kLbKrPJHcxLKYA3q8A              lts-seafood-and-steakhouse-broussard
# 11  tDGBP8mc2hKLqRFhO_K2Ng                          bonefish-grill-lafayette
# 12  mkwRJQWB1Ca_j9aBRXuQPw                                 dwights-lafayette
# 13  UiFYIjY5sttbvI0J_zVHOg       acadiana-poboys-and-cajun-cuisine-lafayette
# 14  lYwCOpqW4QB2nRkjb4lmqQ  spoonbill-watering-hole-and-restaurant-lafayette
# 15  jp6m9Ssgb2sj-Cm9b8gQ6A                        dragos-lafayette-lafayette
# 16  aOIfe9a9WLsp4_azu_S3bA                   ruffinos-on-the-river-lafayette
# 17  Q4OPHhni8IqZzJmNLIGNOg              blu-basil-wine-and-grill-lafayette-2
# 18  1wqSPVCN6zsTl62CHNJW_A                               lagneauxs-lafayette
# 19  XIwKVwG3e8ezLNkd3ZvZ_A                       olde-tyme-grocery-lafayette
#
#                                     name  \
# 0                        The Cajun Table
# 1                        Bon Temps Grill
# 2              Don's Seafood - Lafayette
# 3                      The Crawfish Spot
# 4           Mandez's Seafood Bar & Grill
# 5                Half Shell Oyster House
# 6                   Uncle T's Oyster Bar
# 7                Louisiana Crawfish Time
# 8                              Prejean's
# 9                             Fiery Crab
# 10             LT's Seafood & Steakhouse
# 11                        Bonefish Grill
# 12                              Dwight's
# 13       Acadiana PoBoys & Cajun Cuisine
# 14  Spoonbill Watering Hole & Restaurant
# 15                   Drago's - Lafayette
# 16                Ruffino's On The River
# 17                Blu Basil Wine & Grill
# 18                            Lagneaux's
# 19                     Olde Tyme Grocery
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/DgnTYQ...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/vgoqns...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/DfnwRx...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/a5KYi8...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/Hu_t6e...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/q3wNWJ...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/gA0o_2...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/11SSJL...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/GMMw6X...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/_KjOLP...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/I4GJm5...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/o8HDbl...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/IEBxpT...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/jt3xkA...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/Lv24Z6...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/6F3_BR...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/-adHtW...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/a13ZFA...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/qAV7Th...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/eE4XmI...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-cajun-table-lafay...           158
# 1   https://www.yelp.com/biz/bon-temps-grill-lafay...           952
# 2   https://www.yelp.com/biz/dons-seafood-lafayett...           348
# 3   https://www.yelp.com/biz/the-crawfish-spot-laf...           120
# 4   https://www.yelp.com/biz/mandezs-seafood-bar-a...            79
# 5   https://www.yelp.com/biz/half-shell-oyster-hou...           135
# 6   https://www.yelp.com/biz/uncle-ts-oyster-bar-s...           221
# 7   https://www.yelp.com/biz/louisiana-crawfish-ti...            75
# 8   https://www.yelp.com/biz/prejeans-lafayette-3?...           723
# 9   https://www.yelp.com/biz/fiery-crab-lafayette?...            88
# 10  https://www.yelp.com/biz/lts-seafood-and-steak...           114
# 11  https://www.yelp.com/biz/bonefish-grill-lafaye...           133
# 12  https://www.yelp.com/biz/dwights-lafayette?adj...           107
# 13  https://www.yelp.com/biz/acadiana-poboys-and-c...            39
# 14  https://www.yelp.com/biz/spoonbill-watering-ho...           106
# 15  https://www.yelp.com/biz/dragos-lafayette-lafa...           104
# 16  https://www.yelp.com/biz/ruffinos-on-the-river...           210
# 17  https://www.yelp.com/biz/blu-basil-wine-and-gr...           165
# 18  https://www.yelp.com/biz/lagneauxs-lafayette?a...            65
# 19  https://www.yelp.com/biz/olde-tyme-grocery-laf...           624
#
#                                            categories  rating  \
# 0       [{'alias': 'cajun', 'title': 'Cajun/Creole'}]     4.5
# 1   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 2   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 3   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 4   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 5   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 6   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 7   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 8   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 9          [{'alias': 'seafood', 'title': 'Seafood'}]     2.5
# 10  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 11         [{'alias': 'seafood', 'title': 'Seafood'}]     4.0
# 12  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 13  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 14  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 15         [{'alias': 'seafood', 'title': 'Seafood'}]     3.5
# 16  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 17  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.5
# 18  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.5
# 19  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     4.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 30.1542038, 'longitude': -92.0485...          [delivery]
# 1   {'latitude': 30.2024736, 'longitude': -92.0140...  [delivery, pickup]
# 2      {'latitude': 30.19525, 'longitude': -92.05694}  [delivery, pickup]
# 3       {'latitude': 30.1899, 'longitude': -92.01352}  [delivery, pickup]
# 4   {'latitude': 30.2021924927875, 'longitude': -9...  [delivery, pickup]
# 5   {'latitude': 30.1539250703709, 'longitude': -9...          [delivery]
# 6     {'latitude': 30.235258, 'longitude': -92.09492}          [delivery]
# 7   {'latitude': 30.156499764300143, 'longitude': ...          [delivery]
# 8   {'latitude': 30.306143044990996, 'longitude': ...  [delivery, pickup]
# 9   {'latitude': 30.160371120892343, 'longitude': ...  [delivery, pickup]
# 10   {'latitude': 30.137911, 'longitude': -91.970862}          [delivery]
# 11  {'latitude': 30.1690661, 'longitude': -92.0356...  [delivery, pickup]
# 12     {'latitude': 30.18548, 'longitude': -92.06778}  [delivery, pickup]
# 13   {'latitude': 30.141331, 'longitude': -92.033106}          [delivery]
# 14     {'latitude': 30.22094, 'longitude': -92.01872}  [delivery, pickup]
# 15     {'latitude': 30.20355, 'longitude': -92.04773}          [delivery]
# 16  {'latitude': 30.1787834, 'longitude': -92.0462...          [delivery]
# 17  {'latitude': 30.1801069418035, 'longitude': -9...  [delivery, pickup]
# 18     {'latitude': 30.18052, 'longitude': -92.08781}          [delivery]
# 19     {'latitude': 30.21569, 'longitude': -92.02312}          [delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '4510 Ambassador Caffery', 'addre...  +13378069565
# 1     $$  {'address1': '1211 W Pinhook Rd', 'address2': ...  +13377068850
# 2     $$  {'address1': '4309 Johnston St', 'address2': '...  +13379811141
# 3     $$  {'address1': '1899 W Pinhook Rd', 'address2': ...  +13372378533
# 4     $$  {'address1': '110 Doucet Rd', 'address2': '', ...  +13377693917
# 5     $$  {'address1': '109 Old Camp Rd', 'address2': 'S...  +13374841120
# 6     $$  {'address1': '1001 St Mary St', 'address2': ''...  +13375042285
# 7     $$  {'address1': '2019 Verot School Rd', 'address2...  +13379882645
# 8     $$  {'address1': '3480 NE Evangeline Trwy', 'addre...  +13378963247
# 9    NaN  {'address1': '2330 Kaliste Saloom Rd', 'addres...  +13375348118
# 10    $$  {'address1': '636 Albertson Pkwy', 'address2':...  +13378373268
# 11    $$  {'address1': '1912 Kaliste Saloom Rd', 'addres...  +13379810714
# 12    $$  {'address1': '4800 Johnston St', 'address2': '...  +13379811241
# 13     $  {'address1': '2848 Verot School Rd', 'address2...  +13378562511
# 14    $$  {'address1': '900 Jefferson St', 'address2': '...  +13375340585
# 15   $$$  {'address1': '3151 Johnston St', 'address2': '...  +13377067077
# 16   $$$  {'address1': '921 Camellia Blvd', 'address2': ...  +13377067333
# 17    $$  {'address1': '5451 Johnston St', 'address2': '...  +13374561120
# 18    $$  {'address1': '445 Ridge Rd', 'address2': '', '...  +13379841415
# 19    $$  {'address1': '218 W St Mary Blvd', 'address2':...  +13372358165
#
#      display_phone      distance
# 0   (337) 806-9565   1481.115837
# 1   (337) 706-8850   5283.372659
# 2   (337) 981-1141   4684.858755
# 3   (337) 237-8533   4034.645168
# 4   (337) 769-3917   5081.836529
# 5   (337) 484-1120   1030.500193
# 6   (337) 504-2285  10390.825149
# 7   (337) 988-2645    982.927653
# 8   (337) 896-3247  16465.938790
# 9   (337) 534-8118   1109.705111
# 10  (337) 837-3268   6460.550213
# 11  (337) 981-0714   1226.719947
# 12  (337) 981-1241   4465.928306
# 13  (337) 856-2511   1871.451711
# 14  (337) 534-0585   7130.701049
# 15  (337) 706-7077   5194.882506
# 16  (337) 706-7333   2722.812535
# 17  (337) 456-1120   4376.359631
# 18  (337) 984-1415   5771.263522
# 19  (337) 235-8165   6481.371951

# %% [markdown]
# - Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
(results['total'])/ results_per_page
# Out:
# 11.1

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 12

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %% [markdown]
# # Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                    alias  \
# 0  _eUkcZsTcwpgQ4g3NtJ8sg                bon-temps-grill-lafayette
# 1  uoE_f470PCOozaATDyRpjA         dons-seafood-lafayette-lafayette
# 2  3PZX6hODVlvbaSKAO1j4Ww              the-crawfish-spot-lafayette
# 3  79Jr4VhRUe_k687DqEGasA  mandezs-seafood-bar-and-grill-lafayette
# 4  oe356jU3hGaw2caDZcD-aQ        half-shell-oyster-house-lafayette
#
#                            name  \
# 0               Bon Temps Grill
# 1     Don's Seafood - Lafayette
# 2             The Crawfish Spot
# 3  Mandez's Seafood Bar & Grill
# 4       Half Shell Oyster House
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/vgoqns...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/DfnwRx...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/a5KYi8...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/Hu_t6e...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/q3wNWJ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/bon-temps-grill-lafay...           952
# 1  https://www.yelp.com/biz/dons-seafood-lafayett...           348
# 2  https://www.yelp.com/biz/the-crawfish-spot-laf...           120
# 3  https://www.yelp.com/biz/mandezs-seafood-bar-a...            79
# 4  https://www.yelp.com/biz/half-shell-oyster-hou...           135
#
#                                           categories  rating  \
# 0  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 2  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 3  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 4  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 30.2024736, 'longitude': -92.0140...  [delivery, pickup]
# 1     {'latitude': 30.19525, 'longitude': -92.05694}  [delivery, pickup]
# 2      {'latitude': 30.1899, 'longitude': -92.01352}  [delivery, pickup]
# 3  {'latitude': 30.2021924927875, 'longitude': -9...  [delivery, pickup]
# 4  {'latitude': 30.1539250703709, 'longitude': -9...          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '1211 W Pinhook Rd', 'address2': ...  +13377068850
# 1    $$  {'address1': '4309 Johnston St', 'address2': '...  +13379811141
# 2    $$  {'address1': '1899 W Pinhook Rd', 'address2': ...  +13372378533
# 3    $$  {'address1': '110 Doucet Rd', 'address2': '', ...  +13377693917
# 4    $$  {'address1': '109 Old Camp Rd', 'address2': 'S...  +13374841120
#
#     display_phone     distance
# 0  (337) 706-8850  5283.372659
# 1  (337) 981-1141  4684.858755
# 2  (337) 237-8533  4034.645168
# 3  (337) 769-3917  5081.836529
# 4  (337) 484-1120  1030.500193

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             221 non-null    object
#  1   alias          221 non-null    object
#  2   name           221 non-null    object
#  3   image_url      221 non-null    object
#  4   is_closed      221 non-null    bool
#  5   url            221 non-null    object
#  6   review_count   221 non-null    int64
#  7   categories     221 non-null    object
#  8   rating         221 non-null    float64
#  9   coordinates    221 non-null    object
#  10  transactions   221 non-null    object
#  11  price          140 non-null    object
#  12  location       221 non-null    object
#  13  phone          221 non-null    object
#  14  display_phone  221 non-null    object
#  15  distance       221 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 26.2+ KB

# %% [markdown]
# # Check for duplicates

# %%
# check for duplicate ID's 
df.duplicated(subset='id').sum()
# Out:
# 0

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Lafayette-seafood.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)

# %% [markdown]
# # Compare filesize with os module's os.path.getsize

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 216,656 Bytes
# CSV.GZ FILE: 31,521 Bytes
# the csv.gz is 6.873385996637163 times smaller!
