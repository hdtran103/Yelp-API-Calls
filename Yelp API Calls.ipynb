# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: requests in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yelpapi) (2.31.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2023.7.22)
# Requirement already satisfied: tqdm in /Users/huytran_1/anaconda3/envs/dojo-env/lib/python3.9/site-packages (4.64.1)

# %% [markdown]
# # Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('/Users/huytran_1/.secret/yelp_api.json', 'r') as f:  
    login = json.load(f)

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s=5.0)

# %% [markdown]
# # Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'Louisiana, LA 70508'
term = 'seafood'

# %%
location.split(',')[0]
# Out:
# 'Tustin'

# %%
## Specify folder for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Tustin-seafood.json'

# %% [markdown]
# # Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON folder name is not empty:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Tustin-seafood.json already exists.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %% [markdown]
# # Load JSON FIle and account for previous results

# %% [markdown]
# # Make the first API call to get the first page of data

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 865

# %%
results['region']
# Out:
# {'center': {'longitude': -117.82081604003906, 'latitude': 33.73717766325585}}

# %%
results['businesses']
# Out:
# [{'id': 'cvwddy324vWwesa47hO1rQ',
#   'alias': 'pacific-catch-tustin',
#   'name': 'Pacific Catch',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MVvbkepIZlrCAEvwFd1vPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pacific-catch-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 300,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.722135808376024, 'longitude': -117.7933607},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3040 El Camino Real',
#    'address2': '',
#    'address3': None,
#    'city': 'Tustin',
#    'zip_code': '92782',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3040 El Camino Real', 'Tustin, CA 92782']},
#   'phone': '+17146130300',
#   'display_phone': '(714) 613-0300',
#   'distance': 3040.39011480187},
#  {'id': 'vxFKFgCf39qb_MeJBn_11Q',
#   'alias': 'fresh-off-the-boat-fish-grill-tustin',
#   'name': 'Fresh Off The Boat Fish Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kTOXkeCNZ-T6h9peJYUXrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresh-off-the-boat-fish-grill-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 1222,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.7593034, 'longitude': -117.8255103},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '17582 E 17th St',
#    'address2': 'Ste 105',
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['17582 E 17th St', 'Ste 105', 'Tustin, CA 92780']},
#   'phone': '+17145441900',
#   'display_phone': '(714) 544-1900',
#   'distance': 2498.2562618106776},
#  {'id': 'P6UaGMOGv8i0hTEXHEbUhQ',
#   'alias': 'the-black-marlin-tustin',
#   'name': 'The Black Marlin',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yb-8kgL0FPsrvnLba2kBvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-black-marlin-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 910,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.7402553015911, 'longitude': -117.82396889364},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '560 El Camino Real',
#    'address2': '',
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['560 El Camino Real', 'Tustin, CA 92780']},
#   'phone': '+17149297427',
#   'display_phone': '(714) 929-7427',
#   'distance': 449.56182350337593},
#  {'id': '3S6lKzpyZnLGRQA68pgzfA',
#   'alias': 'long-hai-restaurant-tustin',
#   'name': 'Long Hai Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AtGAAnPNl3xeA2KwUHog5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/long-hai-restaurant-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 397,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.7384103693369,
#    'longitude': -117.824853642306},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '682 El Camino Real',
#    'address2': '',
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['682 El Camino Real', 'Tustin, CA 92780']},
#   'phone': '+17148388118',
#   'display_phone': '(714) 838-8118',
#   'distance': 397.71671389992673},
#  {'id': 'RWAugaLWYZpoO2iUDZ40Xw',
#   'alias': 'seven-grams-tustin',
#   'name': 'Seven Grams',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SVkO6If7aHdESwXFDpwpvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/seven-grams-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 375,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.747672, 'longitude': -117.81093},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1086 Irvine Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1086 Irvine Blvd', 'Tustin, CA 92780']},
#   'phone': '+16576008212',
#   'display_phone': '(657) 600-8212',
#   'distance': 1483.581360272706},
#  {'id': 'ZsNsQchXY0SG5puyDSnqgA',
#   'alias': 'izakaya-habuya-okinawan-dining-tustin-5',
#   'name': 'Izakaya Habuya Okinawan Dining',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q7w4rpApERtr1Sn-vYWgGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/izakaya-habuya-okinawan-dining-tustin-5?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 825,
#   'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'izakaya', 'title': 'Izakaya'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.731655, 'longitude': -117.818424553442},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '14215 Red Hill Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['14215 Red Hill Ave', 'Tustin, CA 92780']},
#   'phone': '+17146797453',
#   'display_phone': '(714) 679-7453',
#   'distance': 652.6971435659524},
#  {'id': 'b6lMxCjNMS1rA9P5USG68w',
#   'alias': 'water-grill-costa-mesa-2',
#   'name': 'Water Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CDBAR7MC6GvO-Zv_xCBMnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/water-grill-costa-mesa-2?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 3383,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.6910598430702,
#    'longitude': -117.885057821652},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '3300 Bristol S',
#    'address2': '',
#    'address3': None,
#    'city': 'Costa Mesa',
#    'zip_code': '92626',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3300 Bristol S', 'Costa Mesa, CA 92626']},
#   'phone': '+19492087060',
#   'display_phone': '(949) 208-7060',
#   'distance': 7848.818769042838},
#  {'id': 'T3X5GoQf6gVTxJlLsPo7uQ',
#   'alias': 'roast-fish-and-bbq-house-tustin',
#   'name': 'Roast Fish & BBQ House',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T58R3J4H_MxQolOqy3eGEg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roast-fish-and-bbq-house-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 9,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.73147677226516, 'longitude': -117.8274336},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1046 Walnut Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1046 Walnut Ave', 'Tustin, CA 92780']},
#   'phone': '+17144030628',
#   'display_phone': '(714) 403-0628',
#   'distance': 881.0848415599135},
#  {'id': '9U7XQBn8F2CxxRQpWQyk_g',
#   'alias': 'the-crab-cooker-tustin',
#   'name': 'The Crab Cooker',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cvxMBg91mPbXJwXi9DSmEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-crab-cooker-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 624,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.7595939, 'longitude': -117.8288854},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '17260 17th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['17260 17th St', 'Tustin, CA 92780']},
#   'phone': '+17145731077',
#   'display_phone': '(714) 573-1077',
#   'distance': 2600.5285115487377},
#  {'id': 'wpqWZ7YtiW5Rf7WZ2jG-QA',
#   'alias': 'kings-fish-house-orange-orange',
#   'name': "King's Fish House - Orange",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vrL1lNbt4_VJWGOFOCGaUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kings-fish-house-orange-orange?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 1704,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.808768562341, 'longitude': -117.86879726538},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1521 W Katella Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Orange',
#    'zip_code': '92867',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1521 W Katella Ave', 'Orange, CA 92867']},
#   'phone': '+17147716655',
#   'display_phone': '(714) 771-6655',
#   'distance': 9112.554136718816},
#  {'id': 'kUIS_wC480NV3JkZel1v9Q',
#   'alias': 'fresh-off-the-boat-fish-grill-santa-ana',
#   'name': 'Fresh Off The Boat Fish Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_qRn1azbw2tBlBwag5ouCg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresh-off-the-boat-fish-grill-santa-ana?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 134,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'tacos', 'title': 'Tacos'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.700324, 'longitude': -117.888607},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1501 W MacArthur Blvd',
#    'address2': 'Unit A',
#    'address3': '',
#    'city': 'Santa Ana',
#    'zip_code': '92704',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1501 W MacArthur Blvd',
#     'Unit A',
#     'Santa Ana, CA 92704']},
#   'phone': '+17147165363',
#   'display_phone': '(714) 716-5363',
#   'distance': 7483.321659249394},
#  {'id': 'dMn5LJKqtv0udH_s2OySEw',
#   'alias': 'o-sea-orange',
#   'name': 'O Sea',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2nWtX4BJv7yqFVhYLSFHZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/o-sea-orange?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 441,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.78731398733508,
#    'longitude': -117.85298440721432},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '109 S Glassell St',
#    'address2': None,
#    'address3': '',
#    'city': 'Orange',
#    'zip_code': '92866',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['109 S Glassell St', 'Orange, CA 92866']},
#   'phone': '+17143633309',
#   'display_phone': '(714) 363-3309',
#   'distance': 6318.41865611544},
#  {'id': 'di-2WO8fNklJY64FTSpkAA',
#   'alias': 'belacan-grill-malaysian-bistro-tustin',
#   'name': 'Belacan Grill - Malaysian Bistro',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Lsq6yl6DnHmTKPfWKt8Snw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/belacan-grill-malaysian-bistro-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 1362,
#   'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#    {'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.758688, 'longitude': -117.827578},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '17460 17th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['17460 17th St', 'Tustin, CA 92780']},
#   'phone': '+17145059908',
#   'display_phone': '(714) 505-9908',
#   'distance': 2472.196064079114},
#  {'id': 'JEweTc228-pgYjiSwBFYEA',
#   'alias': 'simply-fish-seafood-costa-mesa',
#   'name': 'Simply Fish Seafood',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZzvXZieRaW6TAKxKnTjeuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/simply-fish-seafood-costa-mesa?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 264,
#   'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'},
#    {'alias': 'tacos', 'title': 'Tacos'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.67378585266633,
#    'longitude': -117.92091365964492},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1534 Adams Ave',
#    'address2': 'Ste D',
#    'address3': None,
#    'city': 'Costa Mesa',
#    'zip_code': '92626',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1534 Adams Ave', 'Ste D', 'Costa Mesa, CA 92626']},
#   'phone': '+19493937401',
#   'display_phone': '(949) 393-7401',
#   'distance': 11637.071973232123},
#  {'id': 'T7KFbprc1fk2tFpKN_qrJA',
#   'alias': 'tres-islas-seafood-santa-ana',
#   'name': 'Tres islas seafood',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aoVKYvXHfiLDdCpRzUOAAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tres-islas-seafood-santa-ana?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 12,
#   'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.733068, 'longitude': -117.843949},
#   'transactions': [],
#   'location': {'address1': '1714 E Mcfadden Ave Siite H',
#    'address2': None,
#    'address3': '',
#    'city': 'Santa Ana',
#    'zip_code': '92705',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1714 E Mcfadden Ave Siite H', 'Santa Ana, CA 92705']},
#   'phone': '+16572189179',
#   'display_phone': '(657) 218-9179',
#   'distance': 2195.096404577049},
#  {'id': 'WgCwNl6368ARtwUUN5LF6Q',
#   'alias': 'california-fish-grill-irvine-7',
#   'name': 'California Fish Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BGz74iYz3lTDuWVsPLr_4A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/california-fish-grill-irvine-7?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 3082,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.6841898, 'longitude': -117.8092072},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3988 Barranca Pkwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Irvine',
#    'zip_code': '92606',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3988 Barranca Pkwy', 'Irvine, CA 92606']},
#   'phone': '+19496543838',
#   'display_phone': '(949) 654-3838',
#   'distance': 5989.022537979057},
#  {'id': '7HOoiTHQb4pWEwjoqN98pg',
#   'alias': 'crabstation-seafood-shack-santa-ana',
#   'name': 'CrabStation Seafood Shack',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UtUUswHVcS7xCyn2auNxbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crabstation-seafood-shack-santa-ana?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 204,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.701835817951185,
#    'longitude': -117.88688358033232},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3390 S Bristol St',
#    'address2': None,
#    'address3': '',
#    'city': 'Santa Ana',
#    'zip_code': '92704',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3390 S Bristol St', 'Santa Ana, CA 92704']},
#   'phone': '+17148523206',
#   'display_phone': '(714) 852-3206',
#   'distance': 7265.066001819436},
#  {'id': 'm2YZXJSghrzckdNPz5mmaA',
#   'alias': 'ritters-steam-kettle-cooking-santa-ana',
#   'name': "Ritter's Steam Kettle Cooking",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uNaUbPHwknRpdTohK5ch-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ritters-steam-kettle-cooking-santa-ana?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 3086,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.700612, 'longitude': -117.887472},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1421 W MacArthur Blvd',
#    'address2': 'Ste G',
#    'address3': '',
#    'city': 'Santa Ana',
#    'zip_code': '92704',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1421 W MacArthur Blvd',
#     'Ste G',
#     'Santa Ana, CA 92704']},
#   'phone': '+17148501380',
#   'display_phone': '(714) 850-1380',
#   'distance': 7395.537068811051},
#  {'id': 'E2wHM1sBwjzg_gWnxpFNmQ',
#   'alias': 'mariscos-valencia-mexican-restaurant-tustin',
#   'name': 'Mariscos Valencia Mexican Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WlrLgROe3ia8l9smi-Sw5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mariscos-valencia-mexican-restaurant-tustin?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 184,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.7348412677117, 'longitude': -117.83640537411},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '15761 Tustin Village Way',
#    'address2': 'Ste 104',
#    'address3': None,
#    'city': 'Tustin',
#    'zip_code': '92780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['15761 Tustin Village Way',
#     'Ste 104',
#     'Tustin, CA 92780']},
#   'phone': '+16572890163',
#   'display_phone': '(657) 289-0163',
#   'distance': 1464.7715529737268},
#  {'id': 'mKqueTx2dB8K2IoA0-TWdQ',
#   'alias': 'habachihana-grill-orange-3',
#   'name': 'Habachihana Grill ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PcfS0e8kKobPvuxHDxphxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/habachihana-grill-orange-3?adjust_creative=GAXTYfb4qtwMRsCd0avxFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GAXTYfb4qtwMRsCd0avxFw',
#   'review_count': 158,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.79591, 'longitude': -117.836025},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '554 N Tustin St',
#    'address2': None,
#    'address3': '',
#    'city': 'Orange',
#    'zip_code': '92867',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['554 N Tustin St', 'Orange, CA 92867']},
#   'phone': '+16572842200',
#   'display_phone': '(657) 284-2200',
#   'distance': 6680.711995119539}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                        alias  \
# 0   cvwddy324vWwesa47hO1rQ                         pacific-catch-tustin
# 1   vxFKFgCf39qb_MeJBn_11Q         fresh-off-the-boat-fish-grill-tustin
# 2   P6UaGMOGv8i0hTEXHEbUhQ                      the-black-marlin-tustin
# 3   3S6lKzpyZnLGRQA68pgzfA                   long-hai-restaurant-tustin
# 4   RWAugaLWYZpoO2iUDZ40Xw                           seven-grams-tustin
# 5   ZsNsQchXY0SG5puyDSnqgA      izakaya-habuya-okinawan-dining-tustin-5
# 6   b6lMxCjNMS1rA9P5USG68w                     water-grill-costa-mesa-2
# 7   T3X5GoQf6gVTxJlLsPo7uQ              roast-fish-and-bbq-house-tustin
# 8   9U7XQBn8F2CxxRQpWQyk_g                       the-crab-cooker-tustin
# 9   wpqWZ7YtiW5Rf7WZ2jG-QA               kings-fish-house-orange-orange
# 10  kUIS_wC480NV3JkZel1v9Q      fresh-off-the-boat-fish-grill-santa-ana
# 11  dMn5LJKqtv0udH_s2OySEw                                 o-sea-orange
# 12  di-2WO8fNklJY64FTSpkAA        belacan-grill-malaysian-bistro-tustin
# 13  JEweTc228-pgYjiSwBFYEA               simply-fish-seafood-costa-mesa
# 14  T7KFbprc1fk2tFpKN_qrJA                 tres-islas-seafood-santa-ana
# 15  WgCwNl6368ARtwUUN5LF6Q               california-fish-grill-irvine-7
# 16  7HOoiTHQb4pWEwjoqN98pg          crabstation-seafood-shack-santa-ana
# 17  m2YZXJSghrzckdNPz5mmaA       ritters-steam-kettle-cooking-santa-ana
# 18  E2wHM1sBwjzg_gWnxpFNmQ  mariscos-valencia-mexican-restaurant-tustin
# 19  mKqueTx2dB8K2IoA0-TWdQ                   habachihana-grill-orange-3
#
#                                     name  \
# 0                          Pacific Catch
# 1          Fresh Off The Boat Fish Grill
# 2                       The Black Marlin
# 3                    Long Hai Restaurant
# 4                            Seven Grams
# 5         Izakaya Habuya Okinawan Dining
# 6                            Water Grill
# 7                 Roast Fish & BBQ House
# 8                        The Crab Cooker
# 9             King's Fish House - Orange
# 10         Fresh Off The Boat Fish Grill
# 11                                 O Sea
# 12      Belacan Grill - Malaysian Bistro
# 13                   Simply Fish Seafood
# 14                    Tres islas seafood
# 15                 California Fish Grill
# 16             CrabStation Seafood Shack
# 17         Ritter's Steam Kettle Cooking
# 18  Mariscos Valencia Mexican Restaurant
# 19                    Habachihana Grill
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/MVvbke...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/kTOXke...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/yb-8kg...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/AtGAAn...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/SVkO6I...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/Q7w4rp...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/CDBAR7...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/T58R3J...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/cvxMBg...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/vrL1lN...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/_qRn1a...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/2nWtX4...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/Lsq6yl...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/ZzvXZi...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/aoVKYv...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/BGz74i...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/UtUUsw...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/uNaUbP...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/WlrLgR...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/PcfS0e...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/pacific-catch-tustin?...           300
# 1   https://www.yelp.com/biz/fresh-off-the-boat-fi...          1222
# 2   https://www.yelp.com/biz/the-black-marlin-tust...           910
# 3   https://www.yelp.com/biz/long-hai-restaurant-t...           397
# 4   https://www.yelp.com/biz/seven-grams-tustin?ad...           375
# 5   https://www.yelp.com/biz/izakaya-habuya-okinaw...           825
# 6   https://www.yelp.com/biz/water-grill-costa-mes...          3383
# 7   https://www.yelp.com/biz/roast-fish-and-bbq-ho...             9
# 8   https://www.yelp.com/biz/the-crab-cooker-tusti...           624
# 9   https://www.yelp.com/biz/kings-fish-house-oran...          1704
# 10  https://www.yelp.com/biz/fresh-off-the-boat-fi...           134
# 11  https://www.yelp.com/biz/o-sea-orange?adjust_c...           441
# 12  https://www.yelp.com/biz/belacan-grill-malaysi...          1362
# 13  https://www.yelp.com/biz/simply-fish-seafood-c...           264
# 14  https://www.yelp.com/biz/tres-islas-seafood-sa...            12
# 15  https://www.yelp.com/biz/california-fish-grill...          3082
# 16  https://www.yelp.com/biz/crabstation-seafood-s...           204
# 17  https://www.yelp.com/biz/ritters-steam-kettle-...          3086
# 18  https://www.yelp.com/biz/mariscos-valencia-mex...           184
# 19  https://www.yelp.com/biz/habachihana-grill-ora...           158
#
#                                            categories  rating  \
# 0   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 1   [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
# 2   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 3   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 4          [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 5   [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     4.5
# 6          [{'alias': 'seafood', 'title': 'Seafood'}]     4.5
# 7   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     3.5
# 8   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.5
# 9          [{'alias': 'seafood', 'title': 'Seafood'}]     4.0
# 10  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
# 11  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 12  [{'alias': 'malaysian', 'title': 'Malaysian'},...     4.0
# 13  [{'alias': 'fishnchips', 'title': 'Fish & Chip...     4.5
# 14  [{'alias': 'seafoodmarkets', 'title': 'Seafood...     4.5
# 15  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 16  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 17  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 18  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 19  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
#
#                                           coordinates  \
# 0   {'latitude': 33.722135808376024, 'longitude': ...
# 1   {'latitude': 33.7593034, 'longitude': -117.825...
# 2   {'latitude': 33.7402553015911, 'longitude': -1...
# 3   {'latitude': 33.7384103693369, 'longitude': -1...
# 4    {'latitude': 33.747672, 'longitude': -117.81093}
# 5   {'latitude': 33.731655, 'longitude': -117.8184...
# 6   {'latitude': 33.6910598430702, 'longitude': -1...
# 7   {'latitude': 33.73147677226516, 'longitude': -...
# 8   {'latitude': 33.7595939, 'longitude': -117.828...
# 9   {'latitude': 33.808768562341, 'longitude': -11...
# 10  {'latitude': 33.700324, 'longitude': -117.888607}
# 11  {'latitude': 33.78731398733508, 'longitude': -...
# 12  {'latitude': 33.758688, 'longitude': -117.827578}
# 13  {'latitude': 33.67378585266633, 'longitude': -...
# 14  {'latitude': 33.733068, 'longitude': -117.843949}
# 15  {'latitude': 33.6841898, 'longitude': -117.809...
# 16  {'latitude': 33.701835817951185, 'longitude': ...
# 17  {'latitude': 33.700612, 'longitude': -117.887472}
# 18  {'latitude': 33.7348412677117, 'longitude': -1...
# 19   {'latitude': 33.79591, 'longitude': -117.836025}
#
#                                   transactions price  \
# 0                           [delivery, pickup]    $$
# 1                           [delivery, pickup]    $$
# 2                                   [delivery]    $$
# 3                                     [pickup]    $$
# 4                           [pickup, delivery]    $$
# 5                                           []    $$
# 6                                   [delivery]   $$$
# 7                           [delivery, pickup]   NaN
# 8                           [delivery, pickup]    $$
# 9                                   [delivery]    $$
# 10                          [delivery, pickup]    $$
# 11                          [delivery, pickup]    $$
# 12  [pickup, restaurant_reservation, delivery]    $$
# 13                                          []    $$
# 14                                          []   NaN
# 15                          [delivery, pickup]    $$
# 16                                          []    $$
# 17                          [pickup, delivery]    $$
# 18                          [delivery, pickup]    $$
# 19                          [delivery, pickup]    $$
#
#                                              location         phone  \
# 0   {'address1': '3040 El Camino Real', 'address2'...  +17146130300
# 1   {'address1': '17582 E 17th St', 'address2': 'S...  +17145441900
# 2   {'address1': '560 El Camino Real', 'address2':...  +17149297427
# 3   {'address1': '682 El Camino Real', 'address2':...  +17148388118
# 4   {'address1': '1086 Irvine Blvd', 'address2': N...  +16576008212
# 5   {'address1': '14215 Red Hill Ave', 'address2':...  +17146797453
# 6   {'address1': '3300 Bristol S', 'address2': '',...  +19492087060
# 7   {'address1': '1046 Walnut Ave', 'address2': No...  +17144030628
# 8   {'address1': '17260 17th St', 'address2': '', ...  +17145731077
# 9   {'address1': '1521 W Katella Ave', 'address2':...  +17147716655
# 10  {'address1': '1501 W MacArthur Blvd', 'address...  +17147165363
# 11  {'address1': '109 S Glassell St', 'address2': ...  +17143633309
# 12  {'address1': '17460 17th St', 'address2': '', ...  +17145059908
# 13  {'address1': '1534 Adams Ave', 'address2': 'St...  +19493937401
# 14  {'address1': '1714 E Mcfadden Ave Siite H', 'a...  +16572189179
# 15  {'address1': '3988 Barranca Pkwy', 'address2':...  +19496543838
# 16  {'address1': '3390 S Bristol St', 'address2': ...  +17148523206
# 17  {'address1': '1421 W MacArthur Blvd', 'address...  +17148501380
# 18  {'address1': '15761 Tustin Village Way', 'addr...  +16572890163
# 19  {'address1': '554 N Tustin St', 'address2': No...  +16572842200
#
#      display_phone      distance
# 0   (714) 613-0300   3040.390115
# 1   (714) 544-1900   2498.256262
# 2   (714) 929-7427    449.561824
# 3   (714) 838-8118    397.716714
# 4   (657) 600-8212   1483.581360
# 5   (714) 679-7453    652.697144
# 6   (949) 208-7060   7848.818769
# 7   (714) 403-0628    881.084842
# 8   (714) 573-1077   2600.528512
# 9   (714) 771-6655   9112.554137
# 10  (714) 716-5363   7483.321659
# 11  (714) 363-3309   6318.418656
# 12  (714) 505-9908   2472.196064
# 13  (949) 393-7401  11637.071973
# 14  (657) 218-9179   2195.096405
# 15  (949) 654-3838   5989.022538
# 16  (714) 852-3206   7265.066002
# 17  (714) 850-1380   7395.537069
# 18  (657) 289-0163   1464.771553
# 19  (657) 284-2200   6680.711995

# %% [markdown]
# - Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
(results['total'])/ results_per_page
# Out:
# 43.25

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 44

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %% [markdown]
# # Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                 alias  \
# 0  vxFKFgCf39qb_MeJBn_11Q  fresh-off-the-boat-fish-grill-tustin
# 1  P6UaGMOGv8i0hTEXHEbUhQ               the-black-marlin-tustin
# 2  RWAugaLWYZpoO2iUDZ40Xw                    seven-grams-tustin
# 3  3S6lKzpyZnLGRQA68pgzfA            long-hai-restaurant-tustin
# 4  T3X5GoQf6gVTxJlLsPo7uQ       roast-fish-and-bbq-house-tustin
#
#                             name  \
# 0  Fresh Off The Boat Fish Grill
# 1               The Black Marlin
# 2                    Seven Grams
# 3            Long Hai Restaurant
# 4         Roast Fish & BBQ House
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/kTOXke...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/yb-8kg...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/SVkO6I...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/AtGAAn...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/T58R3J...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/fresh-off-the-boat-fi...          1197
# 1  https://www.yelp.com/biz/the-black-marlin-tust...           888
# 2  https://www.yelp.com/biz/seven-grams-tustin?ad...           286
# 3  https://www.yelp.com/biz/long-hai-restaurant-t...           394
# 4  https://www.yelp.com/biz/roast-fish-and-bbq-ho...             6
#
#                                           categories  rating  \
# 0  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 2         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 3  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 4  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 33.7593034, 'longitude': -117.825...  [delivery, pickup]
# 1  {'latitude': 33.7402553015911, 'longitude': -1...          [delivery]
# 2   {'latitude': 33.747672, 'longitude': -117.81093}  [delivery, pickup]
# 3  {'latitude': 33.7384103693369, 'longitude': -1...            [pickup]
# 4  {'latitude': 33.73147677226516, 'longitude': -...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '17582 E 17th St', 'address2': 'S...  +17145441900
# 1    $$  {'address1': '560 El Camino Real', 'address2':...  +17149297427
# 2    $$  {'address1': '1086 Irvine Blvd', 'address2': N...  +16576008212
# 3    $$  {'address1': '682 El Camino Real', 'address2':...  +17148388118
# 4   NaN  {'address1': '1046 Walnut Ave', 'address2': No...  +17144030628
#
#     display_phone     distance
# 0  (714) 544-1900  2498.256262
# 1  (714) 929-7427   449.561824
# 2  (657) 600-8212  1483.581360
# 3  (714) 838-8118   397.716714
# 4  (714) 403-0628   881.084842

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             864 non-null    object
#  1   alias          864 non-null    object
#  2   name           864 non-null    object
#  3   image_url      864 non-null    object
#  4   is_closed      864 non-null    bool
#  5   url            864 non-null    object
#  6   review_count   864 non-null    int64
#  7   categories     864 non-null    object
#  8   rating         864 non-null    float64
#  9   coordinates    864 non-null    object
#  10  transactions   864 non-null    object
#  11  price          779 non-null    object
#  12  location       864 non-null    object
#  13  phone          864 non-null    object
#  14  display_phone  864 non-null    object
#  15  distance       864 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 102.2+ KB

# %% [markdown]
# # Check for duplicates

# %%
# check for duplicate ID's 
df.duplicated(subset='id').sum()
# Out:
# 15

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Tustin-seafood.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)

# %% [markdown]
# # Compare filesize with os module's os.path.getsize

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 851,230 Bytes
# CSV.GZ FILE: 123,527 Bytes
# the csv.gz is 6.891044063241234 times smaller!
